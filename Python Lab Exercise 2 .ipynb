# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
con = sqlite3.connect('python.db')
heart_df = pd.read_csv('heart.csv')

# %%
type(heart_df)
# Out:
# pandas.core.frame.DataFrame

# %%
age_series = heart_df['age']
type(age_series)
# Out:
# pandas.core.series.Series

# %%
heart_df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
age_series.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
heart_df.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %%
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
age_series.head()
# Out:
# 0    63
# 1    37
# 2    41
# 3    56
# 4    57
# Name: age, dtype: int64

# %%
heart_df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
age_series.tail()
# Out:
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, dtype: int64

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
age_series.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 303 entries, 0 to 302
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 303 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB

# %%
heart_df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
age_series.describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
heart_df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
age_series.dtypes
# Out:
# dtype('int64')

# %%
heart_df.shape
# Out:
# (303, 14)

# %%
age_series.shape
# Out:
# (303,)

# %%
sns.set_style('darkgrid')
sns.distplot(a=heart_df['age']);

# For more recent versions of seaborn:
# sns.histplot(data=heart_df['age'], kde=True);
# Out:
# /var/folders/94/wlmy5cks7x52yss0k_3z_zkc0000gn/T/ipykernel_95923/219183722.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=heart_df['age']);

# %%
sns.scatterplot(x=heart_df['age'], y=heart_df['thalach']);

# %%
extra_rows = {'age': [40, 30], 
              'sex': [1, 0], 
              'cp': [0, 0], 
              'trestbps': [120, 130],
              'chol': [240, 200],
              'fbs': [0, 0], 
              'restecg': [1, 0], 
              'thalach': [120, 122], 
              'exang': [0, 1],
              'oldpeak': [0.1, 1.0], 
              'slope': [1, 1], 
              'ca': [0, 1], 
              'thal': [2, 3],
              'target': [0, 0]}
extra_rows
# Out:
# {'age': [40, 30],
#  'sex': [1, 0],
#  'cp': [0, 0],
#  'trestbps': [120, 130],
#  'chol': [240, 200],
#  'fbs': [0, 0],
#  'restecg': [1, 0],
#  'thalach': [120, 122],
#  'exang': [0, 1],
#  'oldpeak': [0.1, 1.0],
#  'slope': [1, 1],
#  'ca': [0, 1],
#  'thal': [2, 3],
#  'target': [0, 0]}

# %%
# Let's first turn this into a DataFrame.
# We can use the .from_dict() method.

missing = pd.DataFrame(extra_rows)
missing
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   40    1   0       120   240    0        1      120      0      0.1      1
# 1   30    0   0       130   200    0        0      122      1      1.0      1
#
#    ca  thal  target
# 0   0     2       0
# 1   1     3       0

# %%
# Now we just need to concatenate the two DataFrames together.
# Note the `ignore_index` parameter! We'll set that to True.
# complete the python code here

df_combined = pd.concat([heart_df, missing], ignore_index=True)

# %%
print(df_combined)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
# 303   40    1   0       120   240    0        1      120      0      0.1
# 304   30    0   0       130   200    0        0      122      1      1.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_augmented = pd.read_csv('heart.csv')

# %%
heart_augmented['test'] = 0

# %%
heart_augmented.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  test
# 0   0     1       1     0
# 1   0     2       1     0
# 2   0     2       1     0
# 3   0     2       1     0
# 4   0     2       1     0

# %%
heart_augmented['chol_trestbps_sum'] = heart_augmented['chol'] + heart_augmented['trestbps']

# %%
heart_augmented.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  test  chol_trestbps_sum
# 0   0     1       1     0                378
# 1   0     2       1     0                380
# 2   0     2       1     0                334
# 3   0     2       1     0                356
# 4   0     2       1     0                474

# %%
heart_augmented['age'] >= 70
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Name: age, Length: 303, dtype: bool

# %%
heart_augmented[heart_augmented['age'] >= 70]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 145   70    1   1       156   245    0        0      143      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 225   70    1   0       145   174    0        1      125      1      2.6
# 234   70    1   0       130   322    0        0      109      0      2.4
# 238   77    1   0       125   304    0        0      162      1      0.0
# 240   70    1   2       160   269    0        1      112      1      2.9
#
#      slope  ca  thal  target  test  chol_trestbps_sum
# 25       2   2     2       1     0                462
# 60       2   1     2       1     0                375
# ...

# %%
heart_augmented[(heart_augmented['age'] >= 70) | (heart_augmented['trestbps'] > 170)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 8     52    1   2       172   199    1        1      162      0      0.5
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 101   59    1   3       178   270    0        0      145      0      4.2
# 110   64    0   0       180   325    0        1      154      1      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 145   70    1   1       156   245    0        0      143      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 203   68    1   2       180   274    1        0      150      1      1.6
# 223   56    0   0       200   288    1        0      133      1      4.0
# 225   70    1   0       145   174    0        1      125      1      2.6
# ...

# %%
at_risk = heart_augmented[(heart_augmented['age'] >= 70) | (heart_augmented['trestbps'] > 170)]


sns.scatterplot(data=at_risk, x='age', y='chol', hue='sex');

# %%
heart_augmented.loc

# %%
heart_augmented.loc[:9, ['age', 'trestbps']]
# Out:
#    age  trestbps
# 0   63       145
# 1   37       130
# 2   41       130
# 3   56       120
# 4   57       120
# 5   57       140
# 6   56       140
# 7   44       120
# 8   52       172
# 9   57       150

# %%
heart_augmented.iloc

# %%
heart_augmented.iloc[3, 0]
# Out:
# 56

# %%
heart_augmented.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  test  chol_trestbps_sum
# 0   0     1       1     0                378
# 1   0     2       1     0                380
# 2   0     2       1     0                334
# 3   0     2       1     0                356
# 4   0     2       1     0                474

# %%
 heart_augmented.iloc[:10, [0, 3]]
# Out:
#    age  trestbps
# 0   63       145
# 1   37       130
# 2   41       130
# 3   56       120
# 4   57       120
# 5   57       140
# 6   56       140
# 7   44       120
# 8   52       172
# 9   57       150

# %%
heart_augmented.mean()
# Out:
# age                   54.366337
# sex                    0.683168
# cp                     0.966997
# trestbps             131.623762
# chol                 246.264026
# fbs                    0.148515
# restecg                0.528053
# thalach              149.646865
# exang                  0.326733
# oldpeak                1.039604
# slope                  1.399340
# ca                     0.729373
# thal                   2.313531
# target                 0.544554
# test                   0.000000
# chol_trestbps_sum    377.887789
# dtype: float64

# %%
heart_augmented.min()
# Out:
# age                   29.0
# sex                    0.0
# cp                     0.0
# trestbps              94.0
# chol                 126.0
# fbs                    0.0
# restecg                0.0
# thalach               71.0
# exang                  0.0
# oldpeak                0.0
# slope                  0.0
# ca                     0.0
# thal                   0.0
# target                 0.0
# test                   0.0
# chol_trestbps_sum    249.0
# dtype: float64

# %%
heart_augmented.max()
# Out:
# age                   77.0
# sex                    1.0
# cp                     3.0
# trestbps             200.0
# chol                 564.0
# fbs                    1.0
# restecg                2.0
# thalach              202.0
# exang                  1.0
# oldpeak                6.2
# slope                  2.0
# ca                     4.0
# thal                   3.0
# target                 1.0
# test                   0.0
# chol_trestbps_sum    679.0
# dtype: float64

# %%
heart_augmented['slope'].value_counts()
# Out:
# slope
# 2    142
# 1    140
# 0     21
# Name: count, dtype: int64

# %%
heart_augmented['sex'].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
heart_augmented['age'].sort_values()
# Out:
# 72     29
# 58     34
# 125    34
# 239    35
# 65     35
#        ..
# 60     71
# 151    71
# 129    74
# 144    76
# 238    77
# Name: age, Length: 303, dtype: int64

# %%
heart_augmented.plot(x='age', y='trestbps', kind='scatter');

# %%
heart_augmented.hist(column='chol');

# %%
heart_augmented.plot(x='age', y='slope', kind='bar');

# %%
men_ages = heart_augmented[heart_augmented['sex'] == 1]['age']

# %%
men_ages.hist()
# Out:
# <Axes: >

# %%
tar1 = heart_augmented[heart_augmented['target'] == 0]
tar2 = heart_augmented[heart_augmented['target'] == 1]

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6)) 

axs[0].scatter(tar1['chol'], tar1['trestbps'], color='blue', alpha=0.6)
axs[0].set_title('Cholesterol vs. Resting Systolic Blood Pressure (Target = 0)')
axs[0].set_xlabel('Cholesterol')
axs[0].set_ylabel('Resting Systolic BP')


axs[1].scatter(tar2['chol'], tar2['trestbps'], color='orange', alpha=0.6)
axs[1].set_title('Cholesterol vs. Resting Systolic Blood Pressure (Target = 1)')
axs[1].set_xlabel('Cholesterol')
axs[1].set_ylabel('Resting Systolic BP')
# Out:
# Text(0, 0.5, 'Resting Systolic BP')
